# %% [markdown]
# <a href="https://colab.research.google.com/github/ale02ziella/ale02ziella/blob/main/ale_inmersion_datos_aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Bienvenidos a mi primer inmersion de datos**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/drive/MyDrive/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas = {"Baños":"Banos","Área":"Area"}
inmuebles = inmuebles.rename(columns=columnas)
inmuebles.sample(15)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 8275  Apartamento       Apartamento en venta en Santa Barbara             2
# 7257  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 7320         Casa                    Casa en venta en Tintala             4
# 4457  Apartamento            Apartamento en venta en Cedritos             3
# 4996  Apartamento             Apartamento en venta en Kennedy             3
# 579   Apartamento            Apartamento en venta en El Batán             3
# 7344         Casa                Casa en venta en Zona Franca             2
# 5501  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 7507  Apartamento                Apartamento en venta en Suba             3
# 9407         Casa                       Casa en venta en Bosa             7
# 6614  Apartamento             Apartamento en venta en Usaquén             3
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles["Valor"][300]
# Out:
# '$ 116.100.000'

# %%
type(inmuebles["Valor"][300:305])
# Out:
# pandas.core.series.Series

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
inmuebles.sample(100)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 4041         Casa                    Casa en venta en Kennedy             3
# 425   Apartamento             Apartamento en venta en Usaquén             3
# 4598  Apartamento      Apartamento en venta en Chico Norte Ii             1
# 4771  Apartamento      Apartamento en venta en Barrios Unidos             2
# 126   Apartamento     Apartamento en venta en Chico Reservado             3
# ...           ...                                         ...           ...
# 4960  Apartamento      Apartamento en venta en Barrios Unidos             3
# 5706  Apartamento         Apartamento en venta en Los Rosales             3
# 89    Apartamento  Apartamento en venta en Zona Noroccidental             2
# 250   Apartamento      Apartamento en venta en Nueva Zelandia             2
# 7669  Apartamento            Apartamento en venta en Cedritos             3
#
#       Banos  Area              Barrio  \
# ...

# %%
(inmuebles.Barrio == "Chico Reservado")
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
sum((inmuebles.Barrio == "Chico Reservado"))
# Out:
# 225

# %%
inmuebles_chico = (inmuebles.Barrio == "Chico Reservado")
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %%
Chico_Reservado = inmuebles[inmuebles_chico]
Chico_Reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
Chico_Reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(10).plot.bar(color="pink")
# Out:
# <Axes: >

# %% [markdown]
# **DESAFIO ALURA. PRIMER AULA**

# %%
datos = inmuebles.groupby("Barrio").Area.mean()
datos.head(10)
# Out:
# Barrio
# Alameda                   97.000000
# Alhambra                 190.411765
# Andes Norte              124.857143
# Antonio Nariño           163.062500
# Barrancas                 70.200000
# Barrios Unidos           185.621564
# Bella Suiza              119.067961
# Bellavista Occidental    286.200000
# Bochica                  134.250000
# Bogotá D.C               133.785714
# Name: Area, dtype: float64

# %%
inmuebles.groupby("Barrio").Area.mean().sort_values(ascending = False).head(10).plot.bar(color="red")
# Out:
# <Axes: xlabel='Barrio'>

# %%
valor_min = min(inmuebles["Valor"])
valor_min
# Out:
# '$ 1.000.000.000'

# %%
valor_max =max(inmuebles["Valor"])
valor_max
# Out:
# '$ 999.000.000'

# %%
inmuebles_barrios_hab_count = inmuebles.groupby("Barrio")["Habitaciones"].value_counts()
inmuebles_barrios_hab_count
# Out:
# Barrio              Habitaciones
# Alameda             3               1
# Alhambra            3               8
#                     4               5
#                     2               3
#                     1               1
#                                    ..
# Zona Noroccidental  8               4
#                     10              2
#                     32              2
#                     11              1
#                     12              1
# Name: Habitaciones, Length: 601, dtype: int64
